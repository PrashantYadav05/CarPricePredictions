# %%
import numpy as np
import pandas as pd
import category_encoders as ce

# %%
frame = pd.read_csv("C:\\Users\\talk2_000\\Desktop\\Python\\DatasetFiles\\CarPricePrediction\\train.csv")
frame01 = pd.read_csv("C:\\Users\\talk2_000\\Desktop\\Python\\DatasetFiles\\CarPricePrediction\\test.csv")

# %%
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
encoder_count = ce.CountEncoder(cols = ['Manufacturer' , 'Model' , 'Color' , 'Doors' ] , handle_unknown = 1)
df1 = encoder_count.fit_transform(frame)

# %%
df1
# Out:
#              ID  Price  Levy  Manufacturer  Model  Prod. year   Category  \
# 0      45654403  13328  1399           982    173        2010       Jeep
# 1      44731507  16621  1018          1069     23        2011       Jeep
# 2      45774419   8467     -           977    446        2006  Hatchback
# 3      45769185   3607   862          1111    149        2011       Jeep
# 4      45809263  11726   446           977    446        2014  Hatchback
# ...         ...    ...   ...           ...    ...         ...        ...
# 19232  45798355   8467     -          2076      8        1999      Coupe
# 19233  45778856  15681   831          3769   1079        2011      Sedan
# 19234  45804997  26108   836          3769    429        2010       Jeep
# 19235  45793526   5331  1288          1069    140        2007       Jeep
# 19236  45813273    470   753          3769   1079        2012      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# ...

# %%
df1["Manufacturer"].value_counts()
# Out:
# 3769    3769
# 3662    3662
# 2076    2076
# 1111    1111
# 1069    1069
# 1049    1049
# 982      982
# 977      977
# 660      660
# 579      579
# 441      441
# 421      421
# 397      397
# 289      289
# 275      275
# 255      255
# 183      183
# 91       182
# 138      138
# 48        96
# 78        78
# 76        76
# 54        54
# 49        49
# 15        45
# 42        42
# 37        37
# 30        30
# 26        26
# 12        24
# 4         20
# 20        20
# 19        19
# 17        17
# 16        16
# 2         14
# 14        14
# 13        13
# 9          9
# 1          8
# 7          7
# 5          5
# 3          3
# Name: Manufacturer, dtype: int64

# %%
frame["Manufacturer"].value_counts()
# Out:
# HYUNDAI          3769
# TOYOTA           3662
# MERCEDES-BENZ    2076
# FORD             1111
# CHEVROLET        1069
#                  ...
# SATURN              1
# HAVAL               1
# LANCIA              1
# TESLA               1
# PONTIAC             1
# Name: Manufacturer, Length: 65, dtype: int64
